# %%
import os
import glob
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib as mpl
from matplotlib import cm
import matplotlib.pyplot as plt

# %% [markdown]
# ## find target tiles

# %%
path = 'D:/ESACover2021/'
files = glob.glob(os.path.join(path, '*.tif'))
files.sort()

# %%
n_low = 3
n_up = 40
e_low = 87
e_up = 115

# %%
import shutil

# %%
for i in range(len(files)):
    if (n_low <= int(files[i][46:48]) <= n_up) and (e_low <= int(files[i][49:52]) <= e_up):
        shutil.copy(files[i], 'D:/LMRB/LC')
        print(files[i])
# Out:
# D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N03E093_Map.tif
# D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N03E096_Map.tif
# D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N03E099_Map.tif
# D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N03E102_Map.tif
# D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N03E105_Map.tif
# D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N03E108_Map.tif
# D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N03E111_Map.tif
# D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N03E114_Map.tif
# D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N06E090_Map.tif
# D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N06E093_Map.tif
# D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N06E096_Map.tif
# D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N06E099_Map.tif
# D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N06E102_Map.tif
# D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N06E105_Map.tif
# D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N06E111_Map.tif
# ...

# %%
tile = pd.read_table('D:/ESAtile.txt', sep='\s+', header=None)
tile
# Out:
#                                                     0
# 0   D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N...
# 1   D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N...
# 2   D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N...
# 3   D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N...
# 4   D:/ESACover2021\ESA_WorldCover_10m_2021_V200_N...
# ..                                                ...
# 87  D:/ESACover2021\ESA_WorldCover_10m_2021_V200_S...
# 88  D:/ESACover2021\ESA_WorldCover_10m_2021_V200_S...
# 89  D:/ESACover2021\ESA_WorldCover_10m_2021_V200_S...
# 90  D:/ESACover2021\ESA_WorldCover_10m_2021_V200_S...
# 91  D:/ESACover2021\ESA_WorldCover_10m_2021_V200_S...
#
# [92 rows x 1 columns]
